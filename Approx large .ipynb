# %%
import os
import time

def fptas_knapsack(items, max_weight, epsilon):
    start_time = time.time()  # Start timing the knapsack function

    max_value = max(item['value'] for item in items)
    n = len(items)
    K = max_value * epsilon / n
    scaled_items = [{'value': int(item['value'] / K), 'weight': item['weight']} for item in items]
    dp = [0] * (max_weight + 1)
    for item in scaled_items:
        for weight in range(max_weight, item['weight'] - 1, -1):
            dp[weight] = max(dp[weight], dp[weight - item['weight']] + item['value'])
    approximate_total_value = int(dp[max_weight] * K)

    end_time = time.time()  # End timing after calculation
    return approximate_total_value, end_time - start_time  # Return both result and time taken

def parse_and_solve_knapsack(filepath, epsilon):
    with open(filepath, 'r') as file:
        lines = file.readlines()
    n_items, max_weight = map(float, lines[0].strip().split())
    n_items, max_weight = int(n_items), int(max_weight)
    items = []
    for line in lines[1:n_items + 1]:
        try:
            value, weight = map(float, line.strip().split())
            items.append({'value': value, 'weight': int(weight)})
        except ValueError as e:
            print(f"Skipping line in {filepath} due to error: {e}")
            continue
    return fptas_knapsack(items, max_weight, epsilon)

epsilon = 0.1

file_paths = [os.path.join('large', f'large_{i}') for i in range(1, 22)]

results = []
for file_path in file_paths:
    solution_file_path = os.path.join('large_solution', os.path.basename(file_path))
    if not os.path.exists(file_path):
        print(f"Data file missing: {file_path}")
        continue
    if not os.path.exists(solution_file_path):
        print(f"Solution file missing: {solution_file_path}")
        continue
    try:
        start_time = time.time()  # Start timing the entire processing for one file
        approx_total_value, knapsack_time = parse_and_solve_knapsack(file_path, epsilon)
        with open(solution_file_path, 'r') as sol_file:
            official_total_value = int(sol_file.read().strip())
        approximation_ratio = approx_total_value / official_total_value if official_total_value != 0 else float('inf')
        end_time = time.time()  # End timing the entire processing
        total_time = end_time - start_time  # Total processing time for one file
        results.append({
            'File': file_path,
            'Approximate Total Value': approx_total_value,
            'Official Total Value': official_total_value,
            'Approximation Ratio': approximation_ratio,
            'Knapsack Function Time': knapsack_time,
            'Total Processing Time': total_time
        })
    except Exception as e:
        print(f"Error processing file {file_path}: {str(e)}")

for result in results:
    print(result)
# Out:
# {'File': 'large/large_1', 'Approximate Total Value': 9141, 'Official Total Value': 9147, 'Approximation Ratio': 0.9993440472285995, 'Knapsack Function Time': 0.00974583625793457, 'Total Processing Time': 0.011142253875732422}
# {'File': 'large/large_2', 'Approximate Total Value': 11233, 'Official Total Value': 11238, 'Approximation Ratio': 0.9995550809752625, 'Knapsack Function Time': 0.014419794082641602, 'Total Processing Time': 0.016298294067382812}
# {'File': 'large/large_3', 'Approximate Total Value': 28852, 'Official Total Value': 28857, 'Approximation Ratio': 0.9998267318155041, 'Knapsack Function Time': 0.1143031120300293, 'Total Processing Time': 0.11556506156921387}
# {'File': 'large/large_4', 'Approximate Total Value': 54499, 'Official Total Value': 54503, 'Approximation Ratio': 0.9999266095444288, 'Knapsack Function Time': 0.4602632522583008, 'Total Processing Time': 0.46118879318237305}
# {'File': 'large/large_5', 'Approximate Total Value': 110625, 'Official Total Value': 110625, 'Approximation Ratio': 1.0, 'Knapsack Function Time': 1.8945600986480713, 'Total Processing Time': 1.8973209857940674}
# {'File': 'large/large_6', 'Approximate Total Value': 276457, 'Official Total Value': 276457, 'Approximation Ratio': 1.0, 'Knapsack Function Time': 12.545895099639893, 'Total Processing Time': 12.549395084381104}
# {'File': 'large/large_7', 'Approximate Total Value': 563647, 'Official Total Value': 563647, 'Approximation Ratio': 1.0, 'Knapsack Function Time': 49.597676038742065, 'Total Processing Time': 49.604434967041016}
# {'File': 'large/large_8', 'Approximate Total Value': 1508, 'Official Total Value': 1514, 'Approximation Ratio': 0.9960369881109643, 'Knapsack Function Time': 0.004754304885864258, 'Total Processing Time': 0.005539894104003906}
# {'File': 'large/large_9', 'Approximate Total Value': 1631, 'Official Total Value': 1634, 'Approximation Ratio': 0.9981640146878825, 'Knapsack Function Time': 0.00961613655090332, 'Total Processing Time': 0.009845972061157227}
# {'File': 'large/large_10', 'Approximate Total Value': 4562, 'Official Total Value': 4566, 'Approximation Ratio': 0.9991239597021463, 'Knapsack Function Time': 0.10050511360168457, 'Total Processing Time': 0.10166668891906738}
# {'File': 'large/large_11', 'Approximate Total Value': 9048, 'Official Total Value': 9052, 'Approximation Ratio': 0.9995581087052585, 'Knapsack Function Time': 0.4459998607635498, 'Total Processing Time': 0.4467170238494873}
# {'File': 'large/large_12', 'Approximate Total Value': 18047, 'Official Total Value': 18051, 'Approximation Ratio': 0.9997784056284971, 'Knapsack Function Time': 1.8878810405731201, 'Total Processing Time': 1.8892161846160889}
# {'File': 'large/large_13', 'Approximate Total Value': 44352, 'Official Total Value': 44356, 'Approximation Ratio': 0.9999098205428804, 'Knapsack Function Time': 12.282486915588379, 'Total Processing Time': 12.31928277015686}
# {'File': 'large/large_14', 'Approximate Total Value': 90200, 'Official Total Value': 90204, 'Approximation Ratio': 0.999955656068467, 'Knapsack Function Time': 49.668745040893555, 'Total Processing Time': 49.674476861953735}
# {'File': 'large/large_15', 'Approximate Total Value': 2387, 'Official Total Value': 2397, 'Approximation Ratio': 0.9958281184814352, 'Knapsack Function Time': 0.004743814468383789, 'Total Processing Time': 0.005196809768676758}
# {'File': 'large/large_16', 'Approximate Total Value': 2692, 'Official Total Value': 2697, 'Approximation Ratio': 0.9981460882461994, 'Knapsack Function Time': 0.009628057479858398, 'Total Processing Time': 0.010776042938232422}
# {'File': 'large/large_17', 'Approximate Total Value': 7112, 'Official Total Value': 7117, 'Approximation Ratio': 0.9992974567935928, 'Knapsack Function Time': 0.0991520881652832, 'Total Processing Time': 0.09975194931030273}
# {'File': 'large/large_18', 'Approximate Total Value': 14385, 'Official Total Value': 14390, 'Approximation Ratio': 0.9996525364836693, 'Knapsack Function Time': 0.44826817512512207, 'Total Processing Time': 0.4492919445037842}
# {'File': 'large/large_19', 'Approximate Total Value': 28914, 'Official Total Value': 28919, 'Approximation Ratio': 0.9998271032884954, 'Knapsack Function Time': 1.866192102432251, 'Total Processing Time': 1.8676111698150635}
# {'File': 'large/large_20', 'Approximate Total Value': 72500, 'Official Total Value': 72505, 'Approximation Ratio': 0.9999310392386732, 'Knapsack Function Time': 12.284026145935059, 'Total Processing Time': 12.287844181060791}
# {'File': 'large/large_21', 'Approximate Total Value': 146914, 'Official Total Value': 146919, 'Approximation Ratio': 0.999965967642034, 'Knapsack Function Time': 50.63299298286438, 'Total Processing Time': 50.6397659778595}
